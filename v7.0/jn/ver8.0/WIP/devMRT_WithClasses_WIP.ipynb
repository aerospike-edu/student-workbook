// %% [markdown]
// <img src="./pngs/Slide1.png"
//      alt="Slide1"
//      style="float: left; margin-right: 10px;"
//      width="1024"
//      height="768"/>

// %% [markdown]
// <img src="./pngs/Slide2.png"
//      alt="Slide2"
//      style="float: left; margin-right: 10px;"
//      width="1024"
//      height="768"/>

// %% [markdown]
// <img src="./pngs/Slide3.png"
//      alt="Slide3"
//      style="float: left; margin-right: 10px;"
//      width="1024"
//      height="768"/>

// %% [markdown]
// <img src="./pngs/Slide4.png"
//      alt="Slide4"
//      style="float: left; margin-right: 10px;"
//      width="1024"
//      height="768"/>

// %% [markdown]
// ## Transactions Need Strong Consistency (SC) mode Namespace
//
// #### Let's reconfigure our namespace **_test_**  to Replication Factor =  1 and strong-consistency true.
// #### Then using asadm, set the namespace roster and recluster.
//
// See https://aerospike.com/docs/tools/asadm/live_cluster_mode_guide#roster-1 for further details on how to set the roster.

// %% [markdown]
// ### Switching Namespace _test_ from AP to SC
//
// #### In a terminal window, follow these steps.
// ```
// $ sudo service aerospike stop
// $ sudo rm /opt/aerospike/data/*.dat
// $ sudo rm /opt/aerospike/smd/*.smd
// $ sudo vi /etc/aerospike/aerospike.conf
// In namespace test { ... Change:
//   replication-factor 1
//   strong-consistency true
//   default-ttl 0
//   nsup-period 0
// ...
//   In storage-engice device {
//      evict-used-pct 0
//
// :wq (Save the changes)
// Then,
// $ sudo service aerospike start
// $ asadm
// Admin> enable
// Admin+> manage roster stage observed ns test
// Pending roster now contains observed nodes.
// Run "manage recluster" for your changes to take effect.
// Admin+> show roster
// ~~~~~~~~~~~~~~~~~~~~Roster (2025-01-26 17:49:34 UTC)~~~~~~~~~~~~~~~~~~~~
//                             Node|Node|Namespace|Current|Pending|Observed
//                                 |  ID|         | Roster| Roster|   Nodes
// ip-172-31-3-62.ec2.internal:3000|*A1 |test     |--     |A1     |A1
// Number of rows: 1
//
// Admin+> manage recluster
// Successfully started recluster
// Admin+> info  (Check output, Cluster Integrity should be True)
// Admin+> exit
// $
// ```

// %% [markdown]
// # Import to run %sh magic cell

// %%
import io.github.spencerpark.ijava.IJava;
import io.github.spencerpark.jupyter.kernel.magic.common.Shell;
IJava.getKernelInstance().getMagics().registerMagics(Shell.class);

// %% [markdown]
// ### Let's wipe out any prior records on the Aerospike Server
// #### We have a namespace **_test_** pre-defined on the server. Lets truncate it using _asadm_.

// %%
%sh asadm --enable -e "manage truncate ns test --no-warn" -h "127.0.0.1"

// %% [markdown]
// # Add Java Client POM Dependency

// %%
%%loadFromPOM
<dependencies>
  <dependency>
    <groupId>com.aerospike</groupId>
    <artifactId>aerospike-client-jdk8</artifactId>
    <version>9.0.3</version>
  </dependency>
</dependencies>

// %% [markdown]
// # Add required Imports

// %%
import com.aerospike.client.AerospikeClient;
import com.aerospike.client.policy.Policy;
import com.aerospike.client.policy.WritePolicy;
import com.aerospike.client.Bin;
import com.aerospike.client.Key;
import com.aerospike.client.Record;
import com.aerospike.client.Value;
System.out.println("Client modules imported.");
// Out:
// Client modules imported.

// %% [markdown]
// ### Insert test records

// %%
%sh aql -f "./aqlScripts/devmrt_data.aql"

// %%
AerospikeClient client = new AerospikeClient("localhost", 3000);
System.out.println("Initialized the client and connected to the cluster.");
// Out:
// Initialized the client and connected to the cluster.

// %%
//Check our data
Policy rPolicy = new Policy();
for(int i=0; i<10; i++){
    System.out.println( "key"+i+ "  :"+ client.get(rPolicy, new Key("test","testset","key"+i)));
}
// Out:
// key0  :(gen:1),(exp:0),(bins:(name:Sandra),(age:34),(gender:f))
// key1  :(gen:1),(exp:0),(bins:(name:Jack),(age:26),(gender:m))
// key2  :(gen:1),(exp:0),(bins:(name:Jill),(age:20),(gender:f))
// key3  :(gen:1),(exp:0),(bins:(name:James),(age:38),(gender:m))
// key4  :(gen:1),(exp:0),(bins:(name:Jim),(age:46),(gender:m))
// key5  :(gen:1),(exp:0),(bins:(name:Julia),(age:62),(gender:f))
// key6  :(gen:1),(exp:0),(bins:(name:Sally),(age:32),(gender:f))
// key7  :(gen:1),(exp:0),(bins:(name:Sean),(age:24),(gender:m))
// key8  :(gen:1),(exp:0),(bins:(name:Sam),(age:12),(gender:m))
// key9  :(gen:1),(exp:0),(bins:(name:Susan),(age:42),(gender:f))

// %% [markdown]
// ### Now that we are set up with a set of Records to play with, let's Continue with Transactions in Aerospike Ver 8.0
//
// ## We were talking about Serializability ...

// %% [markdown]
// <img src="./pngs/Slide4.png"
//      alt="Slide4"
//      style="float: left; margin-right: 10px;"
//      width="1024"
//      height="768"/>

// %% [markdown]
// <img src="./pngs/Slide5.png"
//      alt="Slide5"
//      style="float: left; margin-right: 10px;"
//      width="1024"
//      height="768"/>

// %% [markdown]
// <img src="./pngs/Slide6.png"
//      alt="Slide6"
//      style="float: left; margin-right: 10px;"
//      width="1024"
//      height="768"/>

// %% [markdown]
// <img src="./pngs/Slide7.png"
//      alt="Slide7"
//      style="float: left; margin-right: 10px;"
//      width="1024"
//      height="768"/>

// %% [markdown]
// <img src="./pngs/Slide8.png"
//      alt="Slide8"
//      style="float: left; margin-right: 10px;"
//      width="1024"
//      height="768"/>

// %% [markdown]
// ### **Note**: If Client dies after Read Verification, Monitor will roll the Transaction forward. Otherwise it will roll it back.
//
// ## We were talking about Serializability ...

// %% [markdown]
// <img src="./pngs/Slide9.png"
//      alt="Slide9"
//      style="float: left; margin-right: 10px;"
//      width="1024"
//      height="768"/>

// %% [markdown]
// <img src="./pngs/Slide10.png"
//      alt="Slide10"
//      style="float: left; margin-right: 10px;"
//      width="1024"
//      height="768"/>

// %% [markdown]
// <img src="./pngs/Slide11.png"
//      alt="Slide11"
//      style="float: left; margin-right: 10px;"
//      width="1024"
//      height="768"/>

// %% [markdown]
// <img src="./pngs/Slide12.png"
//      alt="Slide12"
//      style="float: left; margin-right: 10px;"
//      width="1024"
//      height="768"/>

// %% [markdown]
// <img src="./pngs/Slide13.png"
//      alt="Slide13"
//      style="float: left; margin-right: 10px;"
//      width="1024"
//      height="768"/>

// %% [markdown]
// <img src="./pngs/Slide14.png"
//      alt="Slide14"
//      style="float: left; margin-right: 10px;"
//      width="1024"
//      height="768"/>

// %% [markdown]
// ### Check our 3 Records of Interest  &darr;

// %%
//Check our data
Policy rPolicy = new Policy();
for(int i=1; i<4; i++){
    System.out.println( "key"+i+ "  :"+ client.get(rPolicy, new Key("test","testset","key"+i)));
}
// Out:
// key1  :(gen:1),(exp:0),(bins:(name:Jack),(age:26),(gender:m))
// key2  :(gen:1),(exp:0),(bins:(name:Jill),(age:20),(gender:f))
// key3  :(gen:1),(exp:0),(bins:(name:James),(age:38),(gender:m))

// %% [markdown]
// ### Needed Imports for Transactions  &darr;

// %%
//Imports for Transactions
import com.aerospike.client.Txn;
import com.aerospike.client.AerospikeException;
import com.aerospike.client.ResultCode;
import com.aerospike.client.CommitStatus;

// %% [markdown]
// ### Instantiate Txn Object  &darr;
// #### We will use server default TTC of 10 seconds. More than enough. Aerospike reads/writes take milliseconds!
// #### Read and Write policies instantiated with copy constructor and assigned Txn.
// #### Execute the transaction, we are the only client executing right now,check results.

// %%
/// Simple Transaction
Txn txn1 = new Txn();  //Generates unique TxnId for this Transaction
System.out.println("Begin txn1: " + txn1.getId()+"\n");

Policy mrtrpolicy1 = client.copyReadPolicyDefault();  //Create a default read policy copy. (Not a reference.)
mrtrpolicy1.txn = txn1;

WritePolicy mrtwpolicy1 = client.copyWritePolicyDefault();  //Create a default write policy copy. (Not a reference.)
mrtwpolicy1.txn = txn1;

//Both our read and write policies for this transaction are now tied to this Transaction ID.

//We will not worry about processing individual command exceptions. 
//Enclose entire transaction in a single try - catch / all or nothing.
boolean bOK = true;
try {
  //We will read R1:  key1  (Jacks's data)
  Key key1 = new Key("test", "testset", "key1");
  Record reckey1t1 = client.get(mrtrpolicy1, key1); //Save data in this record.

  //Then read R2:  key2 (Jill's data)
  Key key2 = new Key("test", "testset", "key2");
  Record reckey2t1 = client.get(mrtrpolicy1, key2); //Save data in this record.

  //Then update R2: Add a string bin. 
  Bin bTxnUpdate = new Bin("txn", "txn1_update");
  client.put(mrtwpolicy1, key2, bTxnUpdate); //put() returns void. 

  //Update R3: key3 (James' data) Add a string bin
  Key key3 = new Key("test", "testset", "key3");
  bTxnUpdate = new Bin("txn", "txn1_update");
  client.put(mrtwpolicy1, key3, bTxnUpdate); //put() returns void. 
}
catch (AerospikeException e){
    bOK = false;
    System.out.println(e.getMessage());
    client.abort(txn1);
}

//If all good, commit. 
if(bOK){
  try {
    client.commit(txn1);
    txn1.clear();
    mrtrpolicy1.txn = null;
    mrtwpolicy1.txn = null;
  } catch (AerospikeException.Commit cs){   //Commit Status
    //System.out.println(cs.getResultCode());
    if(cs.getResultCode() == ResultCode.TXN_FAILED){
      System.out.println("Transaction failed to commit.\n");
    }
  }
}

//Check our data
Policy rPolicy = new Policy();
for(int i=1; i<4; i++){
    System.out.println( "key"+i+ "  :"+ client.get(rPolicy, new Key("test","testset","key"+i)));
}
// Out:
// Begin txn1: 7194437706322715427
//
// key1  :(gen:1),(exp:0),(bins:(name:Jack),(age:26),(gender:m))
// key2  :(gen:3),(exp:0),(bins:(name:Jill),(age:20),(gender:f),(txn:txn1_update))
// key3  :(gen:3),(exp:0),(bins:(name:James),(age:38),(gender:m),(txn:txn1_update))

// %% [markdown]
// <img src="./pngs/Slide15.png"
//      alt="Slide15"
//      style="float: left; margin-right: 10px;"
//      width="1024"
//      height="768"/>

// %% [markdown]
// <img src="./pngs/Slide16.png"
//      alt="Slide16"
//      style="float: left; margin-right: 10px;"
//      width="1024"
//      height="768"/>

// %% [markdown]
// <img src="./pngs/Slide17.png"
//      alt="Slide17"
//      style="float: left; margin-right: 10px;"
//      width="1024"
//      height="768"/>

// %% [markdown]
// ## RESET OUR DATA SET  &darr;

// %%
%sh asadm --enable -e "manage truncate ns test --no-warn" -h "127.0.0.1"

// %%
%sh aql -f "./aqlScripts/devmrt_data.aql"

// %%
//Check our data, we will be now trying R1 through R4
Policy rPolicy = new Policy();
for(int i=1; i<5; i++){
    System.out.println( "key"+i+ "  :"+ client.get(rPolicy, new Key("test","testset","key"+i)));
}
// Out:
// key1  :(gen:1),(exp:0),(bins:(name:Jack),(age:26),(gender:m))
// key2  :(gen:1),(exp:0),(bins:(name:Jill),(age:20),(gender:f))
// key3  :(gen:1),(exp:0),(bins:(name:James),(age:38),(gender:m))
// key4  :(gen:1),(exp:0),(bins:(name:Jim),(age:46),(gender:m))

// %% [markdown]
// ## Serializability
// ### We will mix up the two transactions TXN1 and TXN2 in our serial execution.  &darr;
// ### Both should succeed.

// %%
/// Two Transactions Interspersed - For Demonstration only from a single threaded execution 
Txn txn1 = new Txn();  //Generates unique TxnId for this Transaction
//System.out.println("Begin txn1: " + txn1.getId());

Txn txn2 = new Txn();  //Generates unique TxnId for this Transaction
//System.out.println("Begin txn2: " + txn2.getId()+"\n");

Policy mrtrpolicy1 = client.copyReadPolicyDefault();  //Create a default read policy copy. (Not a reference.)
mrtrpolicy1.txn = txn1;

WritePolicy mrtwpolicy1 = client.copyWritePolicyDefault();  //Create a default write policy copy. (Not a reference.)
mrtwpolicy1.txn = txn1;


Policy mrtrpolicy2 = client.copyReadPolicyDefault();  //Create a default read policy copy. (Not a reference.)
mrtrpolicy2.txn = txn2;

WritePolicy mrtwpolicy2 = client.copyWritePolicyDefault();  //Create a default write policy copy. (Not a reference.)
mrtwpolicy2.txn = txn2;


//Our read and write policies are now tied to Transaction ID.

boolean bOK = true;
try {
  //TXN1 T0: Write R1
  Key key1 = new Key("test", "testset", "key1");
  Bin bTxnUpdate = new Bin("txn", "txn1_update");
  client.put(mrtwpolicy1, key1, bTxnUpdate); //put() returns void.

  //TXN2 T0: Write R3  (almost T0 !!!)
  Key key3 = new Key("test", "testset", "key3");
  bTxnUpdate = new Bin("txn", "txn2_update");
  client.put(mrtwpolicy2, key3, bTxnUpdate); //put() returns void.

  //TXN1 T1: Read R2:  
  Key key2 = new Key("test", "testset", "key2");
  Record reckey2t1 = client.get(mrtrpolicy1, key2); //Save data in this record.
    
  //TXN1 T2: Read R4:  
  Key key4 = new Key("test", "testset", "key4");
  Record reckey4t2 = client.get(mrtrpolicy2, key4); //Save data in this record.
}
catch (AerospikeException e){
    bOK = false;
    System.out.println(e.getMessage());
    client.abort(txn1);
    client.abort(txn2);
}

//If all good, commit. 
if(bOK){
  try {
    client.commit(txn1);
    txn1.clear();
    mrtrpolicy1.txn = null;
    mrtwpolicy1.txn = null;
  } catch (AerospikeException.Commit cs){   //Commit Status
    //System.out.println(cs.getResultCode());
    if(cs.getResultCode() == ResultCode.TXN_FAILED){
      System.out.println("Transaction failed to commit.");
    }
  }
  try {
    client.commit(txn2);
    txn2.clear();
    mrtrpolicy2.txn = null;
    mrtwpolicy2.txn = null;
  } catch (AerospikeException.Commit cs){   //Commit Status
    //System.out.println(cs.getResultCode());
    if(cs.getResultCode() == ResultCode.TXN_FAILED){
      System.out.println("Transaction failed to commit.");
    }
  }    
}

//Check our data, we will be now trying R1 through R4
Policy rPolicy = new Policy();
for(int i=1; i<5; i++){
    System.out.println( "key"+i+ "  :"+ client.get(rPolicy, new Key("test","testset","key"+i)));
}
// Out:
// Begin txn1: 2884754553022440536
//
// Begin txn2: -8519994569210877133
//
// key1  :(gen:3),(exp:0),(bins:(name:Jack),(age:26),(gender:m),(txn:txn1_update))
// key2  :(gen:1),(exp:0),(bins:(name:Jill),(age:20),(gender:f))
// key3  :(gen:3),(exp:0),(bins:(name:James),(age:38),(gender:m),(txn:txn2_update))
// key4  :(gen:1),(exp:0),(bins:(name:Jim),(age:46),(gender:m))

// %% [markdown]
// ## CHECK &darr;

// %% [markdown]
// <img src="./pngs/Slide17.png"
//      alt="Slide17"
//      style="float: left; margin-right: 10px;"
//      width="1024"
//      height="768"/>

// %% [markdown]
// ## Now Let's Try 7 Transactions in this execution order of various commands on different records &darr;  (Phew!)

// %% [markdown]
// <img src="./pngs/Slide18.png"
//      alt="Slide18"
//      style="float: left; margin-right: 10px;"
//      width="1024"
//      height="768"/>

// %%
%sh asadm --enable -e "manage truncate ns test --no-warn" -h "127.0.0.1"

// %%
%sh aql -f "./aqlScripts/devmrt_data.aql"

// %%
//Check our data, we will be now trying R1 through R9
Policy rPolicy = new Policy();
for(int i=1; i<10; i++){
    System.out.println( "key"+i+ "  :"+ client.get(rPolicy, new Key("test","testset","key"+i)));
}
// Out:
// key1  :(gen:1),(exp:0),(bins:(name:Jack),(age:26),(gender:m))
// key2  :(gen:1),(exp:0),(bins:(name:Jill),(age:20),(gender:f))
// key3  :(gen:1),(exp:0),(bins:(name:James),(age:38),(gender:m))
// key4  :(gen:1),(exp:0),(bins:(name:Jim),(age:46),(gender:m))
// key5  :(gen:1),(exp:0),(bins:(name:Julia),(age:62),(gender:f))
// key6  :(gen:1),(exp:0),(bins:(name:Sally),(age:32),(gender:f))
// key7  :(gen:1),(exp:0),(bins:(name:Sean),(age:24),(gender:m))
// key8  :(gen:1),(exp:0),(bins:(name:Sam),(age:12),(gender:m))
// key9  :(gen:1),(exp:0),(bins:(name:Susan),(age:42),(gender:f))

// %%
// Create 7 Transactions - For Demonstration only from a single threaded execution 
Txn txn1 = new Txn();  
Txn txn2 = new Txn();  
Txn txn3 = new Txn();
Txn txn4 = new Txn();
Txn txn5 = new Txn();
Txn txn6 = new Txn();
Txn txn7 = new Txn();

//Create read and write policies for each Txn

//txn1
Policy mrtrpolicy1 = client.copyReadPolicyDefault();  
mrtrpolicy1.txn = txn1;
WritePolicy mrtwpolicy1 = client.copyWritePolicyDefault();  
mrtwpolicy1.txn = txn1;

//txn2
Policy mrtrpolicy2 = client.copyReadPolicyDefault();  //Create a default read policy copy. (Not a reference.)
mrtrpolicy2.txn = txn2;
WritePolicy mrtwpolicy2 = client.copyWritePolicyDefault();  //Create a default write policy copy. (Not a reference.)
mrtwpolicy2.txn = txn2;

//txn3
Policy mrtrpolicy3 = client.copyReadPolicyDefault();  //Create a default read policy copy. (Not a reference.)
mrtrpolicy3.txn = txn3;
WritePolicy mrtwpolicy3 = client.copyWritePolicyDefault();  //Create a default write policy copy. (Not a reference.)
mrtwpolicy3.txn = txn3;

//txn4
Policy mrtrpolicy4 = client.copyReadPolicyDefault();  //Create a default read policy copy. (Not a reference.)
mrtrpolicy4.txn = txn4;
WritePolicy mrtwpolicy4 = client.copyWritePolicyDefault();  //Create a default write policy copy. (Not a reference.)
mrtwpolicy4.txn = txn4;

//txn5
Policy mrtrpolicy5 = client.copyReadPolicyDefault();  //Create a default read policy copy. (Not a reference.)
mrtrpolicy5.txn = txn5;
WritePolicy mrtwpolicy5 = client.copyWritePolicyDefault();  //Create a default write policy copy. (Not a reference.)
mrtwpolicy5.txn = txn5;

//txn6
Policy mrtrpolicy6 = client.copyReadPolicyDefault();  //Create a default read policy copy. (Not a reference.)
mrtrpolicy6.txn = txn6;
WritePolicy mrtwpolicy6 = client.copyWritePolicyDefault();  //Create a default write policy copy. (Not a reference.)
mrtwpolicy6.txn = txn6;

//txn7
Policy mrtrpolicy7 = client.copyReadPolicyDefault();  //Create a default read policy copy. (Not a reference.)
mrtrpolicy7.txn = txn7;
WritePolicy mrtwpolicy7 = client.copyWritePolicyDefault();  //Create a default write policy copy. (Not a reference.)
mrtwpolicy7.txn = txn7;

//Our read and write policies are now tied to Transaction ID.
// Create all Key objects first
Key key1 = new Key("test", "testset", "key1");
Key key2 = new Key("test", "testset", "key2");
Key key3 = new Key("test", "testset", "key3");
Key key4 = new Key("test", "testset", "key4");
Key key5 = new Key("test", "testset", "key5");
Key key6 = new Key("test", "testset", "key6");
Key key7 = new Key("test", "testset", "key7");
Key key8 = new Key("test", "testset", "key8");
Key key9 = new Key("test", "testset", "key9");

//Bin object
Bin bTxnUpdate = new Bin("txn", "txn_update");

boolean bOK = true;
try {
  //At T0:
    //TXN1: Read R1
    Record reckey1t1 = client.get(mrtrpolicy1, key1);
    
    //TXN2: Read R1
    Record reckey1t2 = client.get(mrtrpolicy2, key1);

    //TXN3: Read R1
    Record reckey1t3 = client.get(mrtrpolicy3, key1);

    //TXN4: Read R1
    Record reckey1t4 = client.get(mrtrpolicy4, key1);
    
    //TXN5: Read R7
    Record reckey7t5 = client.get(mrtrpolicy5, key7);

    //TXN6: Read R7
    Record reckey7t6 = client.get(mrtrpolicy6, key7);
    
    //TXN7: Read R7
    Record reckey7t7 = client.get(mrtrpolicy7, key7);

  //At T1:
    //TXN1: Read R2
    Record reckey2t1 = client.get(mrtrpolicy1, key2);
    
    //TXN2: Read R2
    Record reckey2t2 = client.get(mrtrpolicy2, key2);
    
    //TXN3: Read R3
    Record reckey3t3 = client.get(mrtrpolicy3, key3);
      
    //TXN4: Write R6
    bTxnUpdate = new Bin("txn", "txn4_update");
    client.put(mrtwpolicy4, key6, bTxnUpdate); 

    //TXN5: Read R8
    Record reckey8t5 = client.get(mrtrpolicy5, key8);
    
    //TXN6: Read R8
    Record reckey8t6 = client.get(mrtrpolicy6, key8);
    
    //TXN7: Read R8
    Record reckey8t7 = client.get(mrtrpolicy7, key8);

 //At T2:   

    //TXN1: Write R3
    bTxnUpdate = new Bin("txn", "txn1_update");
    client.put(mrtwpolicy1, key3, bTxnUpdate); 
    
    //TXN2: Write R4
    bTxnUpdate = new Bin("txn", "txn2_update");
    client.put(mrtwpolicy2, key4, bTxnUpdate); 

    //TXN3: Write R5
    bTxnUpdate = new Bin("txn", "txn3_update");
    client.put(mrtwpolicy3, key5, bTxnUpdate); 

    //TXN4: Write R6
    bTxnUpdate = new Bin("txn", "txn4_update");
    client.put(mrtwpolicy4, key6, bTxnUpdate); 
    
    //TXN5: Write R9
    bTxnUpdate = new Bin("txn", "txn5_update");
    client.put(mrtwpolicy5, key9, bTxnUpdate); 

    //TXN6: Write R9
    bTxnUpdate = new Bin("txn", "txn6_update");
    client.put(mrtwpolicy6, key9, bTxnUpdate);     //On Exception ... we will comment it out and re-run

    //TXN7: Read R6
    Record reckey6t7 = client.get(mrtrpolicy7, key6);  //On Exception ... we will comment it out and re-run

    //That's are time matrix of various Transactions and their CRUD commands.

}
catch (AerospikeException e){
    bOK = false;
    System.out.println(e.getMessage());
    client.abort(txn1);
    client.abort(txn2);    
    client.abort(txn3);
    client.abort(txn4);    
    client.abort(txn5);
    client.abort(txn6);    
    client.abort(txn7);   
}

//If all good, commit. 
if(bOK){
  try {
    client.commit(txn1);
    txn1.clear();
    mrtrpolicy1.txn = null;
    mrtwpolicy1.txn = null;
  } catch (AerospikeException.Commit cs){   //Commit Status
    //System.out.println(cs.getResultCode());
    if(cs.getResultCode() == ResultCode.TXN_FAILED){
      System.out.println("Transaction 1 failed to commit.");
    }
  }
  try {
    client.commit(txn2);
    txn2.clear();
    mrtrpolicy2.txn = null;
    mrtwpolicy2.txn = null;
  } catch (AerospikeException.Commit cs){   //Commit Status
    //System.out.println(cs.getResultCode());
    if(cs.getResultCode() == ResultCode.TXN_FAILED){
      System.out.println("Transaction 2 failed to commit.");
    }
  }    
  try {
    client.commit(txn3);
    txn2.clear();
    mrtrpolicy2.txn = null;
    mrtwpolicy2.txn = null;
  } catch (AerospikeException.Commit cs){   //Commit Status
    //System.out.println(cs.getResultCode());
    if(cs.getResultCode() == ResultCode.TXN_FAILED){
      System.out.println("Transaction 3 failed to commit.");
    }
  }  
  try {
    client.commit(txn4);
    txn2.clear();
    mrtrpolicy2.txn = null;
    mrtwpolicy2.txn = null;
  } catch (AerospikeException.Commit cs){   //Commit Status
    //System.out.println(cs.getResultCode());
    if(cs.getResultCode() == ResultCode.TXN_FAILED){
      System.out.println("Transaction 4 failed to commit.");
    }
  } 
  try {
    client.commit(txn5);
    txn2.clear();
    mrtrpolicy2.txn = null;
    mrtwpolicy2.txn = null;
  } catch (AerospikeException.Commit cs){   //Commit Status
    //System.out.println(cs.getResultCode());
    if(cs.getResultCode() == ResultCode.TXN_FAILED){
      System.out.println("Transaction 5 failed to commit.");
    }
  }  
  try {
    client.commit(txn6);
    txn2.clear();
    mrtrpolicy2.txn = null;
    mrtwpolicy2.txn = null;
  } catch (AerospikeException.Commit cs){   //Commit Status
    //System.out.println(cs.getResultCode());
    if(cs.getResultCode() == ResultCode.TXN_FAILED){
      System.out.println("Transaction 6 failed to commit.");
    }
  }  
  try {
    client.commit(txn7);
    txn2.clear();
    mrtrpolicy2.txn = null;
    mrtwpolicy2.txn = null;
  } catch (AerospikeException.Commit cs){   //Commit Status
    //System.out.println(cs.getResultCode());
    if(cs.getResultCode() == ResultCode.TXN_FAILED){
      System.out.println("Transaction 7 failed to commit.");
    }
  }      
}

//Check our data, we will be now trying R1 through R4
Policy rPolicy = new Policy();
for(int i=1; i<10; i++){
    System.out.println( "key"+i+ "  :"+ client.get(rPolicy, new Key("test","testset","key"+i)));
}
// Out:
// Transaction 3 failed to commit.
// key1  :(gen:1),(exp:0),(bins:(name:Jack),(age:26),(gender:m))
// key2  :(gen:1),(exp:0),(bins:(name:Jill),(age:20),(gender:f))
// key3  :(gen:3),(exp:0),(bins:(name:James),(age:38),(gender:m),(txn:txn1_update))
// key4  :(gen:3),(exp:0),(bins:(name:Jim),(age:46),(gender:m),(txn:txn2_update))
// key5  :(gen:3),(exp:0),(bins:(name:Julia),(age:62),(gender:f))
// key6  :(gen:4),(exp:0),(bins:(name:Sally),(age:32),(gender:f),(txn:txn4_update))
// key7  :(gen:1),(exp:0),(bins:(name:Sean),(age:24),(gender:m))
// key8  :(gen:1),(exp:0),(bins:(name:Sam),(age:12),(gender:m))

// %% [markdown]
// ## For above &uarr; run, our Transacations &darr;

// %% [markdown]
// <img src="./pngs/Slide18.png"
//      alt="Slide18"
//      style="float: left; margin-right: 10px;"
//      width="1024"
//      height="768"/>

// %% [markdown]
// ## Next Case of Serializability &darr;

// %% [markdown]
// <img src="./pngs/Slide19.png"
//      alt="Slide19"
//      style="float: left; margin-right: 10px;"
//      width="1024"
//      height="768"/>

// %% [markdown]
// ## Let's check this &uarr; mutual lockup case also &darr;

// %%
%sh asadm --enable -e "manage truncate ns test --no-warn" -h "127.0.0.1"

// %%
%sh aql -f "./aqlScripts/devmrt_data.aql"

// %%
//Check our data, we will be now trying R1 through R9
Policy rPolicy = new Policy();
for(int i=1; i<3; i++){
    System.out.println( "key"+i+ "  :"+ client.get(rPolicy, new Key("test","testset","key"+i)));
}
// Out:
// key1  :(gen:1),(exp:0),(bins:(name:Jack),(age:26),(gender:m))
// key2  :(gen:1),(exp:0),(bins:(name:Jill),(age:20),(gender:f))

// %%
// Create 7 Transactions - For Demonstration only from a single threaded execution 
Txn txn1 = new Txn();  
Txn txn2 = new Txn();  

//Create read and write policies for each Txn

//txn1
Policy mrtrpolicy1 = client.copyReadPolicyDefault();  
mrtrpolicy1.txn = txn1;
WritePolicy mrtwpolicy1 = client.copyWritePolicyDefault();  
mrtwpolicy1.txn = txn1;

//txn2
Policy mrtrpolicy2 = client.copyReadPolicyDefault();  //Create a default read policy copy. (Not a reference.)
mrtrpolicy2.txn = txn2;
WritePolicy mrtwpolicy2 = client.copyWritePolicyDefault();  //Create a default write policy copy. (Not a reference.)
mrtwpolicy2.txn = txn2;

//Our read and write policies are now tied to Transaction ID.
// Create all Key objects first
Key key1 = new Key("test", "testset", "key1");
Key key2 = new Key("test", "testset", "key2");

//Bin object
Bin bTxnUpdate = new Bin("txn", "txn_update");

boolean bOK = true;
try {
  //At T0:
    
    //TXN1: Write R1
    bTxnUpdate = new Bin("txn", "txn1_update");
    client.put(mrtwpolicy1, key1, bTxnUpdate); 
    
    //TXN2: Write R2
    bTxnUpdate = new Bin("txn", "txn2_update");
    client.put(mrtwpolicy2, key2, bTxnUpdate); 

  //At T1:
    
    //TXN1: Read R2
    Record reckey2t1 = client.get(mrtrpolicy1, key2);
    
    //TXN2: Read R1
    Record reckey1t2 = client.get(mrtrpolicy2, key1);
}
catch (AerospikeException e){
    bOK = false;
    System.out.println(e.getMessage());
    client.abort(txn1);
    client.abort(txn2);
}

//If all good, commit. 
if(bOK){
  try {
    client.commit(txn1);
    txn1.clear();
    mrtrpolicy1.txn = null;
    mrtwpolicy1.txn = null;
  } catch (AerospikeException.Commit cs){   //Commit Status
    //System.out.println(cs.getResultCode());
    if(cs.getResultCode() == ResultCode.TXN_FAILED){
      System.out.println("Transaction 1 failed to commit.");
    }
  }
  try {
    client.commit(txn2);
    txn2.clear();
    mrtrpolicy2.txn = null;
    mrtwpolicy2.txn = null;
  } catch (AerospikeException.Commit cs){   //Commit Status
    //System.out.println(cs.getResultCode());
    if(cs.getResultCode() == ResultCode.TXN_FAILED){
      System.out.println("Transaction 2 failed to commit.");
    }
  }         
}

//Check our data, we will be now trying R1 through R4
Policy rPolicy = new Policy();
for(int i=1; i<3; i++){
    System.out.println( "key"+i+ "  :"+ client.get(rPolicy, new Key("test","testset","key"+i)));
}
// Out:
// Error 120,1,0,30000,1000,2,A1 127.0.0.1 3000: Transaction record blocked by a different transaction
// key1  :(gen:1),(exp:0),(bins:(name:Jack),(age:26),(gender:m))
// key2  :(gen:1),(exp:0),(bins:(name:Jill),(age:20),(gender:f))
// key3  :(gen:1),(exp:0),(bins:(name:James),(age:38),(gender:m))
// key4  :(gen:1),(exp:0),(bins:(name:Jim),(age:46),(gender:m))
// key5  :(gen:1),(exp:0),(bins:(name:Julia),(age:62),(gender:f))
// key6  :(gen:1),(exp:0),(bins:(name:Sally),(age:32),(gender:f))
// key7  :(gen:1),(exp:0),(bins:(name:Sean),(age:24),(gender:m))
// key8  :(gen:1),(exp:0),(bins:(name:Sam),(age:12),(gender:m))
// key9  :(gen:1),(exp:0),(bins:(name:Susan),(age:42),(gender:f))

// %% [markdown]
// ## But if we wait on Record Blocke Exception for TXN2, simulated below: &darr;

// %%
// Create 7 Transactions - For Demonstration only from a single threaded execution 
Txn txn1 = new Txn();  
Txn txn2 = new Txn();  

//Create read and write policies for each Txn

//txn1
Policy mrtrpolicy1 = client.copyReadPolicyDefault();  
mrtrpolicy1.txn = txn1;
WritePolicy mrtwpolicy1 = client.copyWritePolicyDefault();  
mrtwpolicy1.txn = txn1;

//txn2
Policy mrtrpolicy2 = client.copyReadPolicyDefault();  //Create a default read policy copy. (Not a reference.)
mrtrpolicy2.txn = txn2;
WritePolicy mrtwpolicy2 = client.copyWritePolicyDefault();  //Create a default write policy copy. (Not a reference.)
mrtwpolicy2.txn = txn2;

//Our read and write policies are now tied to Transaction ID.
// Create all Key objects first
Key key1 = new Key("test", "testset", "key1");
Key key2 = new Key("test", "testset", "key2");

//Bin object
Bin bTxnUpdate = new Bin("txn", "txn_update");

boolean bOK = true;
try {
  //At T0:
    
    //TXN1: Write R1
    bTxnUpdate = new Bin("txn", "txn1_update");
    client.put(mrtwpolicy1, key1, bTxnUpdate); 
    
    //TXN2: Write R2
    bTxnUpdate = new Bin("txn", "txn2_update");
    client.put(mrtwpolicy2, key2, bTxnUpdate); 

  //At T1:
    
    //TXN1: Read R2
    Record reckey2t1 = client.get(mrtrpolicy1, key2);
    
//    //TXN2: Read R1
//    Record reckey1t2 = client.get(mrtrpolicy2, key1);
}
catch (AerospikeException e){
    bOK = false;
    System.out.println(e.getMessage());
    client.abort(txn1);  //Note: We abort Txn1 now since we excepted.  Allows txn2 to complete later.
}

//If all good, commit. 
if(bOK){
  try {
    client.commit(txn1);
    txn1.clear();
    mrtrpolicy1.txn = null;
    mrtwpolicy1.txn = null;
  } catch (AerospikeException.Commit cs){   //Commit Status
    //System.out.println(cs.getResultCode());
    if(cs.getResultCode() == ResultCode.TXN_FAILED){
      System.out.println("Transaction 1 failed to commit.");
    }
  }
}
bOK = true;
try{
    //TXN2: Read R1
    Record reckey1t2 = client.get(mrtrpolicy2, key1);
}
catch (AerospikeException e){
    bOK = false;
    System.out.println(e.getMessage());
}

if(bOK){
  try {
    client.commit(txn2);
    txn2.clear();
    mrtrpolicy2.txn = null;
    mrtwpolicy2.txn = null;
  } catch (AerospikeException.Commit cs){   //Commit Status
    //System.out.println(cs.getResultCode());
    if(cs.getResultCode() == ResultCode.TXN_FAILED){
      System.out.println("Transaction 2 failed to commit.");
    }
  }         
}

//Check our data, we will be now trying R1 through R4
Policy rPolicy = new Policy();
for(int i=1; i<3; i++){
    System.out.println( "key"+i+ "  :"+ client.get(rPolicy, new Key("test","testset","key"+i)));
}
// Out:
// Error 120,1,0,30000,1000,2,A1 127.0.0.1 3000: Transaction record blocked by a different transaction
// key1  :(gen:7),(exp:0),(bins:(name:Jack),(age:26),(gender:m))
// key2  :(gen:7),(exp:0),(bins:(name:Jill),(age:20),(gender:f),(txn:txn2_update))

// %% [markdown]
// ## PRIOR CELLS &darr;

// %%
//MRT 1 - Read transactions
import com.aerospike.client.Txn;
import com.aerospike.client.AerospikeException;
import com.aerospike.client.ResultCode;
import com.aerospike.client.CommitStatus;

Txn txn1 = new Txn();  //Generates unique TxnId for this MRT
System.out.println("Begin txn1: " + txn1.getId());
Policy mrtrpolicy1 = client.copyReadPolicyDefault();  //Create a default read policy copy. (Not a reference.)
mrtrpolicy1.txn = txn1;
    
//Read key1
Key key1 = new Key("test", "testset", "key1");

//Read key2
Key key2 = new Key("bar", "testset", "key2");

Record reckey1t1 = null;

System.out.println("Check non-class based read. \n");
//Record reckey1t1 = record;
//System.out.println("Record Key1: "+ reckey1t1);

//Note: Record not found returns null record but the rest 
// of the MRT transaction can still proceed further.
try {
    reckey1t1 = client.get(mrtrpolicy1, key1);
}catch (AerospikeException ae){
    int rc = ae.getResultCode();
    if(rc == ResultCode.UNSUPPORTED_FEATURE){
        System.out.println("MRT Txn not supported. Check, is namespace SC?");
        //client.abort(txn1);   //Application coding or server namespace configuration error
    }
    else if (rc == ResultCode.CLIENT_ERROR){
        System.out.println("Record is from a different namespace than the one associated with this MRT Txn.");
        System.out.println("MRT Txn namespace is set upon first read or write transaction.");
        //client.abort(txn1);  //Application coding error
    }
    else if (rc == ResultCode.MRT_VERSION_MISMATCH){
        System.out.println("Record version has changed since last read. Txn will not succeed commit.");
        client.abort(txn1);
    }
    else if (rc == ResultCode.MRT_BLOCKED){
        System.out.println("Record is locked by another MRT");
        client.abort(txn1);
    }
    else if (rc == ResultCode.MRT_EXPIRED){
        System.out.println("This MRT transaction's Allowable Duration has expired");
        client.abort(txn1);
    }
    else if (rc == ResultCode.MRT_COMMITTED){
        System.out.println("Txn was already committed. No more reads/writes allowed in this Txn.");
        client.abort(txn1);
    }
    else if (rc == ResultCode.MRT_ABORTED){
        System.out.println("Txn was aborted. No more reads/writes allowed in this Txn.");
        client.abort(txn1);
    }
}

Record reckey2t1 = null;
try {
    reckey2t1 = client.get(mrtrpolicy1, key2);
}catch (AerospikeException ae){
    int rc = ae.getResultCode();
    if(rc == ResultCode.UNSUPPORTED_FEATURE){
        System.out.println("MRT Txn not supported. Check, is namespace SC?");
    }
}
//Done
client.commit(txn1);
txn1.clear();
mrtrpolicy1.txn = null;

System.out.println("Record Key1: "+ reckey1t1);
System.out.println("Record Key2: "+ reckey2t1);

// %%
//MRT 2 - Read transactions
import com.aerospike.client.Txn;

Txn txn2 = new Txn();  //Generates unique TxnId for this MRT
System.out.println("Begin txn2: " + txn2.getId());
Policy mrtrpolicy2 = client.copyReadPolicyDefault();  //Create a default read policy copy. (Not a reference.)
mrtrpolicy2.txn = txn2;
    
//Read key1
Key key1 = new Key("test", "testset", "key1");

//Read key2
Key key2 = new Key("test", "testset", "key2");

Record reckey1t2 = null;
Record reckey2t2 = null;
try {
    reckey1t2 = client.get(mrtrpolicy2, key1);
    reckey2t2 = client.get(mrtrpolicy2, key2);
}catch (AerospikeException ae){
    int rc = ae.getResultCode();
    if(rc == ResultCode.UNSUPPORTED_FEATURE){
        System.out.println("MRT Txn not supported. Check, is namespace SC?");
    }
}

// %%
//MRT 2 - Read transactions, continued



//Done
client.commit(txn2);
txn2.clear();
mrtrpolicy2.txn = null;


System.out.println("Record Key1: "+ reckey1t2);
System.out.println("Record Key2: "+ reckey2t2);

// %%
//MRT 2 & 3 - Mixing two Read Write MRT transactions
import com.aerospike.client.Txn;
import com.aerospike.client.AerospikeException;
import com.aerospike.client.ResultCode;
import com.aerospike.client.CommitStatus;

Txn txn2 = new Txn();  //Generates unique TxnId for this MRT
System.out.println("Begin txn2: " + txn2.getId());
Policy mrtrpolicy2 = client.copyReadPolicyDefault();  //Create a default read policy copy. (Not a reference.)
WritePolicy mrtwpolicy2 = client.copyWritePolicyDefault();  //Create a default write policy copy. (Not a reference.)
mrtrpolicy2.txn = txn2;
mrtwpolicy2.txn = txn2;


Txn txn3 = new Txn();  //Generates unique TxnId for this MRT
System.out.println("Begin txn3: " + txn3.getId());
Policy mrtrpolicy3 = client.copyReadPolicyDefault();  //Create a default read policy copy. (Not a reference.)
WritePolicy mrtwpolicy3 = client.copyWritePolicyDefault();  //Create a default write policy copy. (Not a reference.)
mrtrpolicy3.txn = txn3;
mrtwpolicy3.txn = txn3;
    
//Read key1
Key key1 = new Key("test", "testset", "key1");

//Write key2
Key key2 = new Key("test", "testset", "key2");

//Start with all reads null  (Jupyter Notebook interactive - hold on to previous cell execution values.)
Record reckey1t2 = null;
Record reckey2t2 = null;
Record reckey1t3 = null;
Record reckey2t3 = null;

Record reckey1t2 = client.get(mrtrpolicy2, key1);
Record reckey2t2 = client.get(mrtrpolicy2, key2);

Record reckey1t3 = client.get(mrtrpolicy3, key1);
if(txn3.monitorExists()){
    System.out.println("Txn3 after get - monitor record exists");
}else{
    System.out.println("Txn3 - no monitor record");
}
client.put(mrtwpolicy3, key2, new Bin("age", 26));
Record reckey2t3 = client.get(mrtrpolicy3, key2);

//Key monitorKey = new Key("test", "<ERO~MRT", txn3.getId());
//Record monRec = client.get(null, monitorKey);
//if(client.get(null, monitorKey) == null){
//    System.out.println("Txn3 monitor rec is null.");
//} else {
//     System.out.println("Txn3 monitor rec got created.");
//}
//System.out.println("Txn3 monitor rec after put:" + monRec);
if(txn3.monitorExists()){
    System.out.println("Txn3 after put - monitor record exists");
}else{
    System.out.println("Txn3 - no monitor record");
}
client.abort(txn3);
if(txn3.monitorExists()){
    System.out.println("Txn3 is not aborted");
}else{
    System.out.println("Txn3 after abort - txn3 is aborted");
}
//if(client.get(null, monitorKey) == null){
//System.out.println("Txn3 monitor record deleted, OK to retry MRT.");
//}

try {
    Record reckey2t2 = client.get(mrtrpolicy2, key2);
} catch (AerospikeException ae){
    int rc = ae.getResultCode();
    if(rc == ResultCode.MRT_VERSION_MISMATCH){
      System.out.println("txn2: Read version mismatch.");
      client.abort(txn2);
    }
    else if(rc == ResultCode.MRT_BLOCKED){
      System.out.println("txn2: Read blocked by another MRT.");      
    }
}

client.commit(txn3);
//Done
try {
  client.commit(txn2);
} catch (AerospikeException.Commit cs){   //Commit Status
    
    System.out.println(cs.getResultCode());
    if(cs.getResultCode() == ResultCode.TXN_FAILED){
      System.out.println("txn2: Transaction failed to commit.");
    }

    client.abort(txn2);
}

txn2.clear();
mrtrpolicy2.txn = null;
mrtwpolicy2.txn = null;

//client.commit(txn3);
txn3.clear();
mrtrpolicy3.txn = null;
mrtwpolicy3.txn = null;

System.out.println("Record Key1: "+ reckey1t2);
System.out.println("Record Key2: "+ reckey2t2);
System.out.println("Record Key1: "+ reckey1t3);
System.out.println("Record Key2: "+ reckey2t3);

// %%
%sh asadm --enable -e "manage truncate ns test --no-warn" -h "127.0.0.1"

// %%
%sh aql -f "./aqlScripts/devmrt_data.aql"

// %%
//MRT 2 & 3 - Mixing two transactions
import com.aerospike.client.Txn;

Txn txn3 = new Txn();  //Generates unique TxnId for this MRT
System.out.println("Begin txn3: " + txn3.getId());
Policy mrtrpolicy3 = client.copyReadPolicyDefault();  //Create a default read policy copy. (Not a reference.)
WritePolicy mrtwpolicy3 = client.copyWritePolicyDefault();  //Create a default write policy copy. (Not a reference.)
mrtrpolicy3.txn = txn3;
mrtwpolicy3.txn = txn3;
    
//Read key1
Key key1 = new Key("test", "testset", "key1");

//Write key2
Key key2 = new Key("test", "testset", "key2");

Record reckey1t3 = client.get(mrtrpolicy3, key1);
client.put(mrtwpolicy3, key2, new Bin("age", 26));
Record reckey2t3 = client.get(mrtrpolicy3, key2);

//Done
client.commit(txn3);
txn3.clear();
mrtrpolicy3.txn = null;
mrtwpolicy3.txn = null;

System.out.println("Record Key1: "+ reckey1t3);
System.out.println("Record Key2: "+ reckey2t3);

// %%
//CLASS Cell
class myTest {
  public void foo (Record rec) {
    System.out.println("Calling myTest:foo() to print rec:"+rec);
  }
}

// %%
myTest myobj = new myTest();
myobj.foo(record);

// %% [markdown]
// # MRT ResultCode Defines
//
// ## SC Namespace check
//
// If Namespace is AP, put() get() with policies that have Txn object with raise AerospikeException which will return:
// ```
// try {
//     Record reckey1t1 = client.get(mrtrpolicy1, key1);
// }catch (AerospikeException ae){
//     if(ae.getResultCode() == ResultCode.UNSUPPORTED_FEATURE){
//         System.out.println("MRT Txn not supported. Check, is namespace SC?");
//     }
// }
// ```
// ## Any Transaction Timed out
// ```
// 	/**
// 	 * Client or server has timed out.
// 	 */
// 	public static final int TIMEOUT = 9;
//
//     // (ResultCode.TIMEOUT) ? --> (Check getInDoubt())
// ```
// ## MRT record blocked by a different transaction.
// ```
// 	public static final int MRT_BLOCKED = 120;
// ```
//
// ## MRT read version mismatch identified during commit.
// ### Some other command changed the record outside of the transaction.
// ```
// 	public static final int MRT_VERSION_MISMATCH = 121;
// ```
//
// ## MRT deadline reached without a successful commit or abort.
// ```
// 	public static final int MRT_EXPIRED = 122;
// ```
//
// ## MRT write command limit (4096) exceeded.
// ```
// 	public static final int MRT_TOO_MANY_WRITES = 123;
// ```
//
// ## MRT was already committed.
// ```
// 	public static final int MRT_COMMITTED = 124;
// ```
//
// ## MRT was already aborted.
// ```
// 	public static final int MRT_ABORTED = 125;
// ```
// ## On Commit
// ### Multi-record transaction failed
// ```
// 	public static final int TXN_FAILED = -17;
// ```
// ## Txn Object
//
// - Return MRT state.
//
// 	public Txn.State getState() {
// 		return state;
// 	}
//
//
// - Verify that the MRT state allows future commands.
// ```
// 	public void verifyCommand() {
// 		if (state != Txn.State.OPEN) {
// 			throw new AerospikeException("Command not allowed in current MRT state: " + state);
// 		}
// 	}
// ```
// where Txn.State can be:
// ```
//     public static enum State {
// 		OPEN,
// 		VERIFIED,
// 		COMMITTED,
// 		ABORTED;
// 	}
// ```
//
// - Return if MRT is inDoubt.
//
// 	public boolean getInDoubt() {
// 		return inDoubt;
// 	}
//
// - Clear MRT. Remove all tracked keys.  (Retains RxID and timeout setting, so will operate on same monitor record.)
// ```
//     public void clear() {
//       namespace = null;
//       deadline = 0;
//       reads.clear();
//       writes.clear();
//     }
// ```
// - Txn object verifies each key handed to the transaction has the same namespace. Initially namespace is null. First transaction will set the namespace value. If you mix up namespaces in the same transaction, you will get:
// ```
//   AerospikeException.CLIENT_ERROR = -1.  //(ResultCode.CLIENT_ERROR)
// ```
// Also txn object can only be used if it is in OPEN state. If it is in anyother state, (VERIFIED, COMMITTED, ABORTED) a new read/write transaction in this Txn object (this TxnID) is not permitted.  You have to start a new Txn object.  You can re-use the same object as:
// ```
//     if(txn4 != null) {
//       txn4.clear();
//       txn4 = null;
//     }
//     Txn txn4 = new Txn();  //Generates unique TxnId for this MRT
// ```

// %%
//Imports
import com.aerospike.client.Txn;
import com.aerospike.client.AerospikeException;
import com.aerospike.client.ResultCode;
import com.aerospike.client.CommitStatus;

//CLASS Cell
class MRTResult {
    private Record rec;
    private int status;  //0: success, 1:MRT failed, 2:OK to retry failed transaction
    private String msg;
    
  public MRTResult(){
      rec = null;
      status=0;
      msg="";
  }
  public Record getRec() {
    return rec;
  }
  public int getStatus() {
    return status;
  }
  public String getMsg() {
    return msg;
  }
  public void setRec(Record r) {
    rec = r;
    return;
  }
  public void setStatus(int s) {
    status = s;
    return;
  }
  public void setMsg(String s) {
    msg = s;
    return;
  }
}

// %%
//Imports
import com.aerospike.client.AerospikeClient;

import com.aerospike.client.Txn;
import com.aerospike.client.AerospikeException;
import com.aerospike.client.ResultCode;
import com.aerospike.client.CommitStatus;

import com.aerospike.client.policy.Policy;
import com.aerospike.client.policy.WritePolicy;
import com.aerospike.client.Bin;
import com.aerospike.client.Key;
import com.aerospike.client.Record;
import com.aerospike.client.Value;


//CLASS Cell
class MRTTxn {
  MRTResult  mrtResult = new MRTResult();
  public MRTTxn() {   
   mrtResult.setRec(null);
   mrtResult.setStatus(0);
   mrtResult.setMsg("");
  }

    //readTxn() 
    public MRTResult readTxn (AerospikeClient ac, Policy rPolicy, Key key) {
  
        Record rec = null;  
        int status = 0;
        String msg = "";
      
        try {
            rec = ac.get(rPolicy, key);
        } catch (AerospikeException ae){
        int rc = ae.getResultCode();
            if(rc == ResultCode.UNSUPPORTED_FEATURE){               
                msg = "MRT Txn not supported. Check, is namespace SC?";
                status = 1;
                //Abort Txn. Application coding or server namespace configuration error
            }
            else if (rc == ResultCode.CLIENT_ERROR){                
                msg = "Record is from a different namespace than the one associated with this MRT Txn."; 
                msg = msg + "\nMRT Txn namespace is set upon first read or write transaction.";
                status = 1; //Abort Txn. Application coding error                
            }
            else if (rc == ResultCode.MRT_VERSION_MISMATCH){                
                msg = "Record version has changed since last read. Txn will not succeed commit.";
                status = 1;  //Abort Txn.
            }
            else if (rc == ResultCode.MRT_BLOCKED){
                msg = "Record is locked by another MRT";
                status = 1;  //Abort Txn.                
            }
            else if (rc == ResultCode.MRT_EXPIRED){
                msg = "This MRT transaction's Allowable Duration has expired";
                status = 1;  //Abort Txn.
            }
            else if (rc == ResultCode.MRT_COMMITTED){
                msg = "Txn was already committed. No more reads/writes allowed in this Txn.";
                status = 1;  //Abort Txn.
            }
            else if (rc == ResultCode.MRT_ABORTED){
                msg = "Txn was aborted. No more reads/writes allowed in this Txn.";
                status = 1;  //Abort Txn.
            }
        } 
        mrtResult.setRec(rec);
        mrtResult.setStatus(status);
        mrtResult.setMsg(msg);
        return mrtResult;
    }
    //End readTxn()

    //writeTxn() example with one bin updated
    public MRTResult writeTxn (AerospikeClient ac, WritePolicy wPolicy, Key key, Bin bin) {
        
        int status = 0;
        String msg = "";
        boolean inDoubt = false;
        
        wPolicy.durableDelete = true; 
        //MRTs only allow durable deletes.
        //Last bin set to null will delete the record.
        
        try {
            ac.put(wPolicy, key, bin);
        } catch (AerospikeException ae){
            int rc = ae.getResultCode();
            if(rc == ResultCode.UNSUPPORTED_FEATURE){                
                msg = "MRT Txn not supported. Check, is namespace SC?";
                status = 1;  //Abort Txn. Application coding or server namespace configuration error
            }
            else if (rc == ResultCode.CLIENT_ERROR){
                msg = "Record is from a different namespace than the one associated with this MRT Txn."; 
                msg = msg + "\nMRT Txn namespace is set upon first read or write transaction.";
                status = 1; //Abort Txn. Application coding error
            }
            else if (rc == ResultCode.MRT_VERSION_MISMATCH){                
                msg = "Record version has changed since last read. Txn will not succeed commit.";
                status = 1; //Abort Txn.
            } 
            else if (rc == ResultCode.MRT_TOO_MANY_WRITES){
                msg = "MRT writes have exceeded max limit of 4096 max writes. Write failed.";
                status = 1; //Abort Txn.
            } 
            //Server checks for version mismatch before MRT blocked by presence of a provisional.
            else if (rc == ResultCode.MRT_BLOCKED){
                msg = "Record is locked by another MRT";
                status = 2;  //Application can WAIT and RETRY IF the record was NOT READ BEFORE in this MRT
            }
            else if (rc == ResultCode.MRT_EXPIRED){
                msg = "This MRT transaction's Allowable Duration has expired";
                status = 1; //Abort Txn.
            }
            else if (rc == ResultCode.MRT_COMMITTED){
                msg = "Txn was already committed. No more reads/writes allowed in this Txn.";
                status = 1; //Abort Txn.
            }
            else if (rc == ResultCode.MRT_ABORTED){
                msg = "Txn was aborted. No more reads/writes allowed in this Txn.";
                status = 1; //Abort Txn.
            }
            else if (rc == ResultCode.TIMEOUT){
                //Check inDoubt
                inDoubt = ae.getInDoubt();
                if(!inDoubt){
                    msg = "Txn never made it to server. Retry the write.";
                    status = 3; //RETRY without waiting.
                } 
                else {
                    Policy rP = ac.copyReadPolicyDefault();
                    MRTResult mrtReadResult = readTxn(ac, rP, key);  //Re-read the record
                    int readStatus = mrtReadResult.getStatus();
                    if(readStatus == 1){  //Read failed for any number of reasons, including version verification
                        status = 1;  //Abort Txn.
                    } else if(readStatus == 0) { //Read succeeded, 
                    }
                }
                msg = "Txn was aborted. No more reads/writes allowed in this Txn.";
                status = 1; //Abort Txn.
            }
        } 
        mrtResult.setRec(null);
        mrtResult.setStatus(status);
        mrtResult.setMsg(msg);
        return mrtResult;
    }
    //End writeTxn()

    //commitTxn()
    public MRTResult commitTxn (AerospikeClient ac, Txn txn) {
        Record rec = null;  
        int status = 0;
        String msg = "";
        try {
            ac.commit(txn);
        } catch (AerospikeException.Commit cs){   //Commit Status
    
            //System.out.println(cs.getResultCode());
            if(cs.getResultCode() == ResultCode.TXN_FAILED){
                msg = "Transaction failed to commit.";
                status = 1;
                client.abort(txn);
            }
        }
        mrtResult.setRec(null);
        mrtResult.setStatus(status);
        mrtResult.setMsg(msg);
        return mrtResult;  
    }
    //End commitTxn()
}

// %%
%sh aql -f "./aqlScripts/insert_bar.aql"

// %%
//MRT Txn4 - Mixing two Namespaces in same MRT object / Checking consequence
import com.aerospike.client.Txn;
import com.aerospike.client.AerospikeException;
import com.aerospike.client.ResultCode;
import com.aerospike.client.CommitStatus;

if(txn4 != null) {
    txn4.clear();
    txn4 = null;
}

Txn txn4 = new Txn();  //Generates unique TxnId for this MRT
System.out.println("Begin txn4: " + txn4.getId());
Policy mrtrpolicy4 = client.copyReadPolicyDefault();  //Create a default read policy copy. (Not a reference.)
WritePolicy mrtwpolicy4 = client.copyWritePolicyDefault();  //Create a default write policy copy. (Not a reference.)
mrtrpolicy4.txn = txn4;
mrtwpolicy4.txn = txn4;
    
//Key1
Key key1 = new Key("test", "testset", "key1");
Key key2 = new Key("test", "testset", "key2");

//Key4
Key key4 = new Key("bar", "testset", "key4");

//Start with all reads null  (Jupyter Notebook interactive - hold on to previous cell execution values.)
Record reckey1t4 = null;
Record reckey2t4 = null;
Record reckey1t4 = null;
Record reckey2t4 = null;

Record reckey1t4 = client.get(mrtrpolicy4, key1);
Record reckey2t4 = client.get(mrtrpolicy4, key2);
client.abort(txn4);
//txn4.clear();
//txn4 = null;
//txn4 = new Txn();
//mrtrpolicy4.txn = txn4;

Record reckey4t4 = client.get(mrtrpolicy4, key4);
//client.put(mrtwpolicy4, key4, new Bin("age", 126));
//Record reckey4t4 = client.get(mrtrpolicy4, key4);
/*
try {
    Record reckey2t2 = client.get(mrtrpolicy2, key2);
} catch (AerospikeException ae){
    if(ae.getResultCode() == ResultCode.MRT_VERSION_MISMATCH){
      System.out.println("txn2: Read version mismatch.");
      client.abort(txn2);
    }
    if(ae.getResultCode() == ResultCode.MRT_BLOCKED){
      System.out.println("txn2: Read blocked by another MRT.");      
    }
}

client.commit(txn3);
//Done
try {
  client.commit(txn2);
} catch (AerospikeException.Commit cs){   //Commit Status
    
    System.out.println(cs.getResultCode());
    if(cs.getResultCode() == ResultCode.TXN_FAILED){
      System.out.println("txn2: Transaction failed to commit.");
    }

    client.abort(txn2);
}

txn2.clear();
mrtrpolicy2.txn = null;
mrtwpolicy2.txn = null;

//client.commit(txn3);
txn3.clear();
mrtrpolicy3.txn = null;
mrtwpolicy3.txn = null;
*/
System.out.println("Record Key1: "+ reckey1t4);
System.out.println("Record Key2: "+ reckey2t4);
System.out.println("Record Key4: "+ reckey4t4);

// %% [markdown]
// # Cleanup

// %%
%sh asadm --enable -e "manage sindex delete idx_age ns test set testset"

// %%
%sh asadm --enable -e "manage truncate ns test --no-warn" -h "127.0.0.1"
